# %%
# for some basic operations
import numpy as np
import pandas as pd

# %%
# for data visualizations
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Upoading dataset
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8929f889-4a90-4426-ba32-3161fbd3284b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8929f889-4a90-4426-ba32-3161fbd3284b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Admission_Predict_Ver1.1.csv to Admission_Predict_Ver1.1.csv

# %%
#Loading Dataset
data = pd.read_csv('Admission_Predict_Ver1.1.csv')
data.shape
data.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  ...  CGPA  Research  Chance of Admit
# 0           1        337          118  ...  9.65         1              0.92
# 1           2        324          107  ...  8.87         1              0.76
# 2           3        316          104  ...  8.00         1              0.72
# 3           4        322          110  ...  8.67         1              0.80
# 4           5        314          103  ...  8.21         0              0.65
#
# [5 rows x 9 columns]

# %%
# describing the dataset
data.describe()
# Out:
#        Serial No.   GRE Score  ...    Research  Chance of Admit
# count  500.000000  500.000000  ...  500.000000         500.00000
# mean   250.500000  316.472000  ...    0.560000           0.72174
# std    144.481833   11.295148  ...    0.496884           0.14114
# min      1.000000  290.000000  ...    0.000000           0.34000
# 25%    125.750000  308.000000  ...    0.000000           0.63000
# 50%    250.500000  317.000000  ...    1.000000           0.72000
# 75%    375.250000  325.000000  ...    1.000000           0.82000
# max    500.000000  340.000000  ...    1.000000           0.97000
#
# [8 rows x 9 columns]

# %%
# checking if the data contains any NULL values
data.isnull().any().any()
# Out:
# False

# %%
# Minimum GRE Score of the students

gre = data['GRE Score'].min()
toefl = data['TOEFL Score'].min()
cgpa = data['CGPA'].min()

# sop - statement of purpose
# lor - letter of recommendation

sop = np.round(data['SOP'].min())
lor = np.round(data['LOR '].min())

research = np.round(data['Research'].min())
uni_rating = np.round(data['University Rating'].min())

# printing the results

print("The Minimum Score for GRE is {:.2f}".format(gre))
print("The Minimum Score for TOEFL is {:.2f}".format(toefl))
print("The Minimum CGPA is {:.2f}".format(cgpa))
print("The Minimum Number for Statement of Purpose is", sop)
print("The Minimum Number for Recommendation letters among the students is", lor)
print("The Minimum Number of Research done by students is ", research)
print("The Minimum University Ratings of Different Students is ", uni_rating)
# Out:
# The Minimum Score for GRE is 290.00
# The Minimum Score for TOEFL is 92.00
# The Minimum CGPA is 6.80
# The Minimum Number for Statement of Purpose is 1.0
# The Minimum Number for Recommendation letters among the students is 1.0
# The Minimum Number of Research done by students is  0
# The Minimum University Ratings of Different Students is  1

# %%
# Maximum GRE Score of the students

gre = data['GRE Score'].max()
toefl = data['TOEFL Score'].max()
cgpa = data['CGPA'].max()

# sop - statement of purpose
# lor - letter of recommendation

sop = np.round(data['SOP'].max())
lor = np.round(data['LOR '].max())

research = np.round(data['Research'].max())
uni_rating = np.round(data['University Rating'].max())

# printing the results

print("The Maximum Score for GRE is {:.2f}".format(gre))
print("The Maximum Score for TOEFL is {:.2f}".format(toefl))
print("The Maximum CGPA is {:.2f}".format(cgpa))
print("The Maximum Number for Statement of Purpose is", sop)
print("The Maximum Number for Recommendation letters among the students is", lor)
print("The Maximum Number of Research done by students is ", research)
print("The Maximum University Ratings of Different Students is ", uni_rating)
# Out:
# The Maximum Score for GRE is 340.00
# The Maximum Score for TOEFL is 120.00
# The Maximum CGPA is 9.92
# The Maximum Number for Statement of Purpose is 5.0
# The Maximum Number for Recommendation letters among the students is 5.0
# The Maximum Number of Research done by students is  1
# The Maximum University Ratings of Different Students is  5

# %%
# Average GRE Score of the students

gre = data['GRE Score'].mean()
toefl = data['TOEFL Score'].mean()
cgpa = data['CGPA'].mean()

# sop - statement of purpose
# lor - letter of recommendation

sop = np.round(data['SOP'].mean())
lor = np.round(data['LOR '].mean())

research = np.round(data['Research'].mean())
uni_rating = np.round(data['University Rating'].mean())

# printing the results

print("The Average Score for GRE is {:.2f}".format(gre))
print("The Average Score for TOEFL is {:.2f}".format(toefl))
print("The Average CGPA is {:.2f}".format(cgpa))
print("The Average Number for Statement of Purpose is", sop)
print("The Average Number for Recommendation letters among the students is", lor)
print("The Average Number of Research done by students is ", research)
print("The Average University Ratings of Different Students is ", uni_rating)
# Out:
# The Average Score for GRE is 316.47
# The Average Score for TOEFL is 107.19
# The Average CGPA is 8.58
# The Average Number for Statement of Purpose is 3.0
# The Average Number for Recommendation letters among the students is 3.0
# The Average Number of Research done by students is  1.0
# The Average University Ratings of Different Students is  3.0

# %%
# plotting a pair plot to see the correlations

plt.rcParams['figure.figsize'] = (20, 9)

sns.pairplot(data,hue = 'Chance of Admit ', palette = 'husl')
plt.title('Pair plot for the data', fontsize = 20)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
# looking at the variations of gre score among the students

plt.rcParams['figure.figsize'] = (20, 9)

sns.distplot(data['GRE Score'], color = 'chartreuse', kde = True)
plt.title('Variations in GRE Score', fontsize = 20)
plt.xlabel('GRE Score')
plt.ylabel('count')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# looking at the variations of toefl score among the students

plt.rcParams['figure.figsize'] = (20, 9)

sns.distplot(data['TOEFL Score'], color = 'violet', kde = True)
plt.title('Variations in TOEFL Score', fontsize = 30)
plt.xlabel('TOEFL Score')
plt.ylabel('count')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# looking at the variations of CGPA among the students

plt.rcParams['figure.figsize'] = (20, 9)

sns.distplot(data['CGPA'], color = 'cadetblue', kde = True)
plt.title('Variations in CGPA', fontsize = 20)
plt.xlabel('CGPA Score')
plt.ylabel('count')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# looking at the variations of LOR among the students

plt.rcParams['figure.figsize'] = (20, 9)

sns.displot(data['LOR '],color = 'springgreen', kde = True, height=9, aspect=2.1 )
plt.title('Variations in Letter of Recommendations', fontsize = 30)
plt.xlabel('LOR Score')
plt.ylabel('count')
plt.show()

# %%
# looking at the variations of SOP among the students

plt.rcParams['figure.figsize'] = (20, 9)

sns.displot(data['SOP'], palette = 'crest', kde = True, height=9, aspect=2.1 )
plt.title('Variations of SOP among the students', fontsize = 30)
plt.xlabel('SOP Score')
plt.ylabel('count')
plt.show()

# %%
# making a pie chart for the analysis of students rather they did research or not.

data_re = data['Research'].value_counts()

label_re = data_re.index
size_re = data_re.values

colors = ['aqua', 'gold']

plt.pie(data_re, labels=label_re, colors=colors, startangle=90, autopct = '%1.2f%%')

centre_circle = plt.Circle((0,0),0.25,color='white', fc='white',linewidth=1.25)
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

plt.title('Research Done or not')
plt.show()

# %%
# making a pie chart for the analysis of students with different university ratings

data1_re = data['University Rating'].value_counts()

label1_re = data1_re.index
size1_re = data1_re.values

colors1 = ['aqua', 'salmon','violet', 'gold', 'lawngreen']

plt.pie(data1_re, labels=label1_re, colors=colors1, startangle=90, autopct = '%1.2f%%')


centre_circle = plt.Circle((0,0),0.25,color='white', fc='white',linewidth=1.25)
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

plt.axis('equal') # Try commenting this out.
plt.title('University Ratings on Students')
plt.show()

# %%
# Analyzing the Chances of Admission

plt.rcParams['figure.figsize'] = (20,9)

stemlines = plt.stem(data['TOEFL Score'], data['Chance of Admit '])
plt.setp(stemlines, color = 'orchid', linewidth = 0.2)
plt.title('Chances of Students According to TOEFL Score', fontsize = 24)
plt.xlabel('TOEFL SCORE', fontsize = 18)
plt.ylabel('Chances of a student to get an Admission', fontsize = 18)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   """

# %%
# Analyzing the Chances of Admission

plt.rcParams['figure.figsize'] = (20,9)

stemlines = plt.stem(data['GRE Score'], data['Chance of Admit '])
plt.setp(stemlines, color = 'sienna', linewidth = 0.2)
plt.title('Chances of Students According to GRE Score', fontsize = 24)
plt.xlabel('GRE SCORE', fontsize = 18)
plt.ylabel('Chances of a student to get an Admission', fontsize = 18)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   """

# %%
# Analyzing the Chances of Admission

plt.rcParams['figure.figsize'] = (20,9)

stemlines = plt.stem(data['SOP'], data['Chance of Admit '])
plt.setp(stemlines, color = 'lightcoral', linewidth = 0.2)
plt.title('Chances of Students According to Student of Purpose', fontsize = 24)
plt.xlabel('Student of Purpose', fontsize = 18)
plt.ylabel('Chances of a student to get an Admission', fontsize = 18)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   """

# %%
# Analyzing the Chances of Admission

plt.rcParams['figure.figsize'] = (20,9)

stemlines = plt.stem(data['CGPA'], data['Chance of Admit '])
plt.setp(stemlines, color = 'lightcoral', linewidth = 0.2)
plt.title('Chances of Students According to CGPA', fontsize = 24)
plt.xlabel('CGPA', fontsize = 18)
plt.ylabel('Chances of a student to get an Admission', fontsize = 18)
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   """

# %%
# Analyzing the Criteria of admission of rated Universities

plt.rcParams['figure.figsize'] = (20,9)
ax = sns.boxplot(x=data['University Rating'], y=data['GRE Score'], color= 'gold', saturation=0.75)
plt.title('University Rating vs GRE Score')
# Out:
# Text(0.5, 1.0, 'University Rating vs GRE Score')

# %%
# Analyzing the Criteria of admission of rated Universities

plt.rcParams['figure.figsize'] = (20,9)
ax = sns.boxplot(x=data['University Rating'], y=data['TOEFL Score'], color= 'aqua')
plt.title('University Rating vs TOEFL Score')
# Out:
# Text(0.5, 1.0, 'University Rating vs TOEFL Score')

# %%
# Analyzing the Criteria of admission of rated Universities

plt.rcParams['figure.figsize'] = (20,9)
ax = sns.boxplot(x=data['University Rating'], y=data['CGPA'], color="plum")
plt.title('University Rating vs CGPA')
# Out:
# Text(0.5, 1.0, 'University Rating vs CGPA')

# %%
x = data.iloc[:, :-1]
y = data.iloc[:, -1]
x
# Out:
#      Serial No.  GRE Score  TOEFL Score  ...  LOR   CGPA  Research
# 0             1        337          118  ...   4.5  9.65         1
# 1             2        324          107  ...   4.5  8.87         1
# 2             3        316          104  ...   3.5  8.00         1
# 3             4        322          110  ...   2.5  8.67         1
# 4             5        314          103  ...   3.0  8.21         0
# ..          ...        ...          ...  ...   ...   ...       ...
# 495         496        332          108  ...   4.0  9.02         1
# 496         497        337          117  ...   5.0  9.87         1
# 497         498        330          120  ...   5.0  9.56         1
# 498         499        312          103  ...   5.0  8.43         0
# 499         500        327          113  ...   4.5  9.04         0
#
# [500 rows x 8 columns]

# %%
y
# Out:
# 0      0.92
# 1      0.76
# 2      0.72
# 3      0.80
# 4      0.65
#        ...
# 495    0.87
# 496    0.96
# 497    0.93
# 498    0.73
# 499    0.84
# Name: Chance of Admit , Length: 500, dtype: float64
